# %% [markdown]
# # Supermarket Sales Data - Beginner Practice Notebook
#
# This notebook contains a simple dataset with 50 rows of supermarket sales data.
# Use the empty cells below to practice your data analysis skills!

# %%
# Import libraries
import pandas as pd
import numpy as np

# Create the supermarket sales dataframe
data = {
    'Product': ['Milk', 'Bread', 'Eggs', 'Cheese', 'Butter', 'Yogurt', 'Chicken', 'Rice', 'Pasta', 'Tomatoes',
                'Milk', 'Bread', 'Eggs', 'Cheese', 'Butter', 'Yogurt', 'Chicken', 'Rice', 'Pasta', 'Tomatoes',
                'Milk', 'Bread', 'Eggs', 'Cheese', 'Butter', 'Yogurt', 'Chicken', 'Rice', 'Pasta', 'Tomatoes',
                'Milk', 'Bread', 'Eggs', 'Cheese', 'Butter', 'Yogurt', 'Chicken', 'Rice', 'Pasta', 'Tomatoes',
                'Milk', 'Bread', 'Eggs', 'Cheese', 'Butter', 'Yogurt', 'Chicken', 'Rice', 'Pasta', 'Tomatoes'],

    'Quantity': [2, 1, 12, 1, 2, 4, 3, 1, 2, 5,
                 3, 2, 6, 2, 1, 3, 2, 2, 1, 3,
                 1, 1, 12, 1, 1, 2, 4, 1, 3, 4,
                 2, 2, 6, 2, 2, 5, 1, 1, 2, 6,
                 4, 1, 12, 1, 1, 4, 3, 2, 1, 2],

    'Price': [3.50, 2.20, 4.80, 5.50, 4.00, 1.50, 12.00, 3.20, 2.50, 1.00,
              3.50, 2.20, 4.80, 5.50, 4.00, 1.50, 12.00, 3.20, 2.50, 1.00,
              3.50, 2.20, 4.80, 5.50, 4.00, 1.50, 12.00, 3.20, 2.50, 1.00,
              3.50, 2.20, 4.80, 5.50, 4.00, 1.50, 12.00, 3.20, 2.50, 1.00,
              3.50, 2.20, 4.80, 5.50, 4.00, 1.50, 12.00, 3.20, 2.50, 1.00],

    'Category': ['Dairy', 'Bakery', 'Dairy', 'Dairy', 'Dairy', 'Dairy', 'Meat', 'Grocery', 'Grocery', 'Produce',
                 'Dairy', 'Bakery', 'Dairy', 'Dairy', 'Dairy', 'Dairy', 'Meat', 'Grocery', 'Grocery', 'Produce',
                 'Dairy', 'Bakery', 'Dairy', 'Dairy', 'Dairy', 'Dairy', 'Meat', 'Grocery', 'Grocery', 'Produce',
                 'Dairy', 'Bakery', 'Dairy', 'Dairy', 'Dairy', 'Dairy', 'Meat', 'Grocery', 'Grocery', 'Produce',
                 'Dairy', 'Bakery', 'Dairy', 'Dairy', 'Dairy', 'Dairy', 'Meat', 'Grocery', 'Grocery', 'Produce'],

    'Store': ['Store A', 'Store A', 'Store B', 'Store A', 'Store B', 'Store A', 'Store B', 'Store A', 'Store B', 'Store A',
              'Store B', 'Store A', 'Store A', 'Store B', 'Store A', 'Store B', 'Store A', 'Store B', 'Store A', 'Store B',
              'Store A', 'Store B', 'Store B', 'Store A', 'Store A', 'Store B', 'Store A', 'Store A', 'Store B', 'Store A',
              'Store B', 'Store B', 'Store A', 'Store B', 'Store B', 'Store A', 'Store B', 'Store B', 'Store A', 'Store B',
              'Store A', 'Store A', 'Store A', 'Store B', 'Store B', 'Store A', 'Store B', 'Store A', 'Store A', 'Store B']
}

df = pd.DataFrame(data)

# Display the first few rows
print("First 10 rows of the dataset:")
print(df.head(10))
print("\nDataset shape:", df.shape)
print("\nColumn names:", df.columns.tolist())
# Out:
# First 10 rows of the dataset:
#     Product  Quantity  Price Category    Store
# 0      Milk         2    3.5    Dairy  Store A
# 1     Bread         1    2.2   Bakery  Store A
# 2      Eggs        12    4.8    Dairy  Store B
# 3    Cheese         1    5.5    Dairy  Store A
# 4    Butter         2    4.0    Dairy  Store B
# 5    Yogurt         4    1.5    Dairy  Store A
# 6   Chicken         3   12.0     Meat  Store B
# 7      Rice         1    3.2  Grocery  Store A
# 8     Pasta         2    2.5  Grocery  Store B
# 9  Tomatoes         5    1.0  Produce  Store A
#
# Dataset shape: (50, 5)
#
# Column names: ['Product', 'Quantity', 'Price', 'Category', 'Store']

# %% [markdown]
# ---
# ## Exercise 1: Display basic information about the dataset
# **Hint:** Use `df.info()` to see data types and non-null counts

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Product   50 non-null     object
#  1   Quantity  50 non-null     int64
#  2   Price     50 non-null     float64
#  3   Category  50 non-null     object
#  4   Store     50 non-null     object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.1+ KB

# %% [markdown]
# ---
# ## Exercise 2: Get statistical summary of numerical columns
# **Hint:** Use `df.describe()` to see count, mean, std, min, max, etc.

# %%
df.describe()
# Out:
#         Quantity      Price
# count  50.000000  50.000000
# mean    2.960000   4.020000
# std     2.717742   3.005369
# min     1.000000   1.000000
# 25%     1.000000   2.200000
# 50%     2.000000   3.350000
# 75%     3.750000   4.800000
# max    12.000000  12.000000

# %% [markdown]
# ---
# ## Exercise 3: Calculate total sales (Quantity × Price)
# **Hint:** Create a new column called 'Total_Sales' by multiplying Quantity and Price columns

# %%
total_sales =  df['Quantity'] * df['Price']
df['Total_Sales'] = total_sales
df.head()
# Out:
#   Product  Quantity  Price Category    Store  Total_Sales
# 0    Milk         2    3.5    Dairy  Store A          7.0
# 1   Bread         1    2.2   Bakery  Store A          2.2
# 2    Eggs        12    4.8    Dairy  Store B         57.6
# 3  Cheese         1    5.5    Dairy  Store A          5.5
# 4  Butter         2    4.0    Dairy  Store B          8.0

# %% [markdown]
# ---
# ## Exercise 4: Find the total revenue from all sales
# **Hint:** Use `df['Total_Sales'].sum()` to add up all sales

# %%
df['Total_Sales'].sum()
# Out:
# np.float64(602.1999999999999)

# %% [markdown]
# ---
# ## Exercise 5: Find the average price of products
# **Hint:** Use `df['Price'].mean()`

# %%
df['Price'].mean()
# Out:
# np.float64(4.02)

# %% [markdown]
# ---
# ## Exercise 6: Count how many unique products are in the dataset
# **Hint:** Use `df['Product'].nunique()`

# %%
df['Product'].nunique()
# Out:
# 10

# %% [markdown]
# ---
# ## Exercise 7: Count how many times each product appears
# **Hint:** Use `df['Product'].value_counts()`

# %%
df['Product'].value_counts()
# Out:
# Product
# Milk        5
# Bread       5
# Eggs        5
# Cheese      5
# Butter      5
# Yogurt      5
# Chicken     5
# Rice        5
# Pasta       5
# Tomatoes    5
# Name: count, dtype: int64

# %% [markdown]
# ---
# ## Exercise 8: Filter the data to show only 'Dairy' category products
# **Hint:** Use `df[df['Category'] == 'Dairy']`

# %%
df[df['Category'] == 'Dairy']
# Out:
#    Product  Quantity  Price Category    Store  Total_Sales
# 0     Milk         2    3.5    Dairy  Store A          7.0
# 2     Eggs        12    4.8    Dairy  Store B         57.6
# 3   Cheese         1    5.5    Dairy  Store A          5.5
# 4   Butter         2    4.0    Dairy  Store B          8.0
# 5   Yogurt         4    1.5    Dairy  Store A          6.0
# 10    Milk         3    3.5    Dairy  Store B         10.5
# 12    Eggs         6    4.8    Dairy  Store A         28.8
# 13  Cheese         2    5.5    Dairy  Store B         11.0
# 14  Butter         1    4.0    Dairy  Store A          4.0
# 15  Yogurt         3    1.5    Dairy  Store B          4.5
# 20    Milk         1    3.5    Dairy  Store A          3.5
# 22    Eggs        12    4.8    Dairy  Store B         57.6
# 23  Cheese         1    5.5    Dairy  Store A          5.5
# 24  Butter         1    4.0    Dairy  Store A          4.0
# 25  Yogurt         2    1.5    Dairy  Store B          3.0
# ...

# %% [markdown]
# ---
# ## Exercise 9: Filter products with Price greater than $4
# **Hint:** Use `df[df['Price'] > 4]`

# %%
df[df['Price'] > 4]
# Out:
#     Product  Quantity  Price Category    Store  Total_Sales
# 2      Eggs        12    4.8    Dairy  Store B         57.6
# 3    Cheese         1    5.5    Dairy  Store A          5.5
# 6   Chicken         3   12.0     Meat  Store B         36.0
# 12     Eggs         6    4.8    Dairy  Store A         28.8
# 13   Cheese         2    5.5    Dairy  Store B         11.0
# 16  Chicken         2   12.0     Meat  Store A         24.0
# 22     Eggs        12    4.8    Dairy  Store B         57.6
# 23   Cheese         1    5.5    Dairy  Store A          5.5
# 26  Chicken         4   12.0     Meat  Store A         48.0
# 32     Eggs         6    4.8    Dairy  Store A         28.8
# 33   Cheese         2    5.5    Dairy  Store B         11.0
# 36  Chicken         1   12.0     Meat  Store B         12.0
# 42     Eggs        12    4.8    Dairy  Store A         57.6
# 43   Cheese         1    5.5    Dairy  Store B          5.5
# 46  Chicken         3   12.0     Meat  Store B         36.0

# %% [markdown]
# ---
# ## Exercise 10: Group by Category and calculate total sales per category
# **Hint:** Use `df.groupby('Category')['Total_Sales'].sum()`

# %%
df.groupby('Category')['Total_Sales'].sum()
# Out:
# Category
# Bakery      15.4
# Dairy      365.9
# Grocery     44.9
# Meat       156.0
# Produce     20.0
# Name: Total_Sales, dtype: float64

# %% [markdown]
# ---
# ## Exercise 11: Group by Store and calculate average quantity sold
# **Hint:** Use `df.groupby('Store')['Quantity'].mean()`

# %%
df.groupby('Store')['Quantity'].mean()
# Out:
# Store
# Store A    2.884615
# Store B    3.041667
# Name: Quantity, dtype: float64

# %% [markdown]
# ---
# ## Exercise 12: Sort the dataframe by Price in descending order
# **Hint:** Use `df.sort_values('Price', ascending=False)`

# %%
df.sort_values('Price', ascending=False)
# Out:
#      Product  Quantity  Price Category    Store  Total_Sales
# 16   Chicken         2   12.0     Meat  Store A         24.0
# 6    Chicken         3   12.0     Meat  Store B         36.0
# 36   Chicken         1   12.0     Meat  Store B         12.0
# 46   Chicken         3   12.0     Meat  Store B         36.0
# 26   Chicken         4   12.0     Meat  Store A         48.0
# 13    Cheese         2    5.5    Dairy  Store B         11.0
# 23    Cheese         1    5.5    Dairy  Store A          5.5
# 3     Cheese         1    5.5    Dairy  Store A          5.5
# 43    Cheese         1    5.5    Dairy  Store B          5.5
# 33    Cheese         2    5.5    Dairy  Store B         11.0
# 22      Eggs        12    4.8    Dairy  Store B         57.6
# 32      Eggs         6    4.8    Dairy  Store A         28.8
# 2       Eggs        12    4.8    Dairy  Store B         57.6
# 12      Eggs         6    4.8    Dairy  Store A         28.8
# ...

# %% [markdown]
# ---
# ## Exercise 13: Find the product with the maximum price
# **Hint:** Use `df[df['Price'] == df['Price'].max()]` or `df.loc[df['Price'].idxmax()]`

# %%
df[df['Price'] == df['Price'].max()]
# Out:
#     Product  Quantity  Price Category    Store  Total_Sales
# 6   Chicken         3   12.0     Meat  Store B         36.0
# 16  Chicken         2   12.0     Meat  Store A         24.0
# 26  Chicken         4   12.0     Meat  Store A         48.0
# 36  Chicken         1   12.0     Meat  Store B         12.0
# 46  Chicken         3   12.0     Meat  Store B         36.0

# %% [markdown]
# ---
# ## Exercise 14: Create a simple bar chart of sales by category
# **Hint:** Use `df.groupby('Category')['Total_Sales'].sum().plot(kind='bar')`
#
# Don't forget to import matplotlib: `import matplotlib.pyplot as plt`

# %%
import matplotlib.pyplot as plt
df.groupby('Category')['Total_Sales'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %% [markdown]
# ---
# ## Bonus Exercise: Create a pivot table showing total sales by Store and Category
# **Hint:** Use `pd.pivot_table(df, values='Total_Sales', index='Store', columns='Category', aggfunc='sum')`

# %%
pd.pivot_table(df, values='Total_Sales', index='Store', columns='Category', aggfunc='sum')
# Out:
# Category  Bakery  Dairy  Grocery  Meat  Produce
# Store
# Store A      8.8  178.2     22.8  72.0      9.0
# Store B      6.6  187.7     22.1  84.0     11.0
