# %% [markdown]
# # Supermarket Sales – Beginner Practice Notebook
#
# Only Cell 1 has code. Rest are hints only.

# %%
import pandas as pd

data = {
    "Invoice_ID": list(range(1001, 1051)),
    "Product": [
        "Rice", "Sugar", "Milk", "Bread", "Eggs",
        "Rice", "Milk", "Bread", "Oil", "Sugar",
        "Eggs", "Rice", "Milk", "Bread", "Oil",
        "Sugar", "Eggs", "Rice", "Milk", "Bread",
        "Oil", "Sugar", "Eggs", "Rice", "Milk",
        "Bread", "Oil", "Sugar", "Eggs", "Rice",
        "Milk", "Bread", "Oil", "Sugar", "Eggs",
        "Rice", "Milk", "Bread", "Oil", "Sugar",
        "Eggs", "Rice", "Milk", "Bread", "Oil",
        "Sugar", "Eggs", "Rice", "Milk", "Bread"
    ],
    "Category": [
        "Grains", "Grocery", "Dairy", "Bakery", "Poultry"
    ] * 10,
    "Quantity": [
        5, 3, 2, 4, 12,
        6, 1, 3, 2, 4,
        10, 8, 2, 5, 1,
        6, 9, 7, 3, 4,
        2, 5, 11, 6, 2,
        4, 1, 3, 10, 7,
        2, 5, 1, 4, 8,
        6, 2, 3, 1, 5,
        9, 7, 2, 4, 1,
        3, 6, 8, 3,8
    ],
    "Price": [
        60, 45, 30, 40, 6,
        60, 30, 40, 150, 45,
        6, 60, 30, 40, 150,
        45, 6, 60, 30, 40,
        150, 45, 6, 60, 30,
        40, 150, 45, 6, 60,
        30, 40, 150, 45, 6,
        60, 30, 40, 150, 45,
        6, 60, 30, 40, 150,
        45, 6, 60, 35,40
    ]
}

df = pd.DataFrame(data)
df
# Out:
#     Invoice_ID Product Category  Quantity  Price
# 0         1001    Rice   Grains         5     60
# 1         1002   Sugar  Grocery         3     45
# 2         1003    Milk    Dairy         2     30
# 3         1004   Bread   Bakery         4     40
# 4         1005    Eggs  Poultry        12      6
# 5         1006    Rice   Grains         6     60
# 6         1007    Milk  Grocery         1     30
# 7         1008   Bread    Dairy         3     40
# 8         1009     Oil   Bakery         2    150
# 9         1010   Sugar  Poultry         4     45
# 10        1011    Eggs   Grains        10      6
# 11        1012    Rice  Grocery         8     60
# 12        1013    Milk    Dairy         2     30
# 13        1014   Bread   Bakery         5     40
# 14        1015     Oil  Poultry         1    150
# 15        1016   Sugar   Grains         6     45
# 16        1017    Eggs  Grocery         9      6
# 17        1018    Rice    Dairy         7     60
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Invoice_ID  50 non-null     int64
#  1   Product     50 non-null     object
#  2   Category    50 non-null     object
#  3   Quantity    50 non-null     int64
#  4   Price       50 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
print (df.head(5))
# Out:
#    Invoice_ID Product Category  Quantity  Price
# 0        1001    Rice   Grains         5     60
# 1        1002   Sugar  Grocery         3     45
# 2        1003    Milk    Dairy         2     30
# 3        1004   Bread   Bakery         4     40
# 4        1005    Eggs  Poultry        12      6

# %%
df['Quantity'].value_counts()
# Out:
# Quantity
# 2     8
# 3     7
# 4     6
# 1     6
# 5     5
# 6     5
# 8     4
# 7     3
# 9     2
# 10    2
# 12    1
# 11    1
# Name: count, dtype: int64

# %%
df['Price'].mean()
# Out:
# np.float64(52.66)

# %%
df['Product'].value_counts()
# Out:
# Product
# Rice     9
# Milk     9
# Bread    9
# Sugar    8
# Eggs     8
# Oil      7
# Name: count, dtype: int64

# %%
df[df['Category'] == 'Dairy']
# Out:
#     Invoice_ID Product Category  Quantity  Price
# 2         1003    Milk    Dairy         2     30
# 7         1008   Bread    Dairy         3     40
# 12        1013    Milk    Dairy         2     30
# 17        1018    Rice    Dairy         7     60
# 22        1023    Eggs    Dairy        11      6
# 27        1028   Sugar    Dairy         3     45
# 32        1033     Oil    Dairy         1    150
# 37        1038   Bread    Dairy         3     40
# 42        1043    Milk    Dairy         2     30
# 47        1048    Rice    Dairy         8     60

# %%
Total_Amount = df['Quantity']*df['Price']
df['Total_Amount'] = Total_Amount
df.head()
# Out:
#    Invoice_ID Product Category  Quantity  Price  Total_Amount
# 0        1001    Rice   Grains         5     60           300
# 1        1002   Sugar  Grocery         3     45           135
# 2        1003    Milk    Dairy         2     30            60
# 3        1004   Bread   Bakery         4     40           160
# 4        1005    Eggs  Poultry        12      6            72

# %%
df['Product'].max()
# Out:
# 'Sugar'

# %%
import matplotlib.pyplot as plt
df.groupby('Category')['Total_Amount'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>
